# %% [markdown]
# # TW1
#
# ## Pandas Series and DataFrame
#
# - Practice Pandas Series and DataFrame with examples.

# %% [markdown]
# #### Write full names of your team members who worked together.
# Madeline Ambrose
#
#
#
# #### Submission:
#
# - Push the completed code to your Github repository.

# %% [markdown]
# ## Part 0
#
# Practice Pandas Series and DataFrame with the given examples.

# %%
import pandas as pd

# %%
alist = ['Mouse', 'Giraffe', 'Tiger', 'Dog', 'Hippopotamus', 'Moose', 'Bear']
animals = pd.Series(alist)
animals
# Out:
# 0           Mouse
# 1         Giraffe
# 2           Tiger
# 3             Dog
# 4    Hippopotamus
# 5           Moose
# 6            Bear
# dtype: object

# %%
animals[2]
# Out:
# 'Tiger'

# %%
animals.iloc[2]
# Out:
# 'Tiger'

# %%
animals.loc[2]
# Out:
# 'Tiger'

# %%
s1 = pd.Series(alist, index=[0, 1, 2, 3, 4, 5, 6])
s1
# Out:
# 0           Mouse
# 1         Giraffe
# 2           Tiger
# 3             Dog
# 4    Hippopotamus
# 5           Moose
# 6            Bear
# dtype: object

# %%
s2 = pd.Series(alist, index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])
s2
# Out:
# a           Mouse
# b         Giraffe
# c           Tiger
# d             Dog
# e    Hippopotamus
# f           Moose
# g            Bear
# dtype: object

# %%
s2['c']
# Out:
# 'Tiger'

# %%
s2.loc['c']
# Out:
# 'Tiger'

# %%
s2.iloc[2]
# Out:
# 'Tiger'

# %%
names = ['Chris', 'Kevin', 'Bob', 'Vinod', 'Daniel', 'Fil', 'Stephanie']
owners = pd.Series(names)
owners
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# dtype: object

# %%
frame = {'animals': animals, 'owners': owners}

df = pd.DataFrame(frame)

df
# Out:
#         animals     owners
# 0         Mouse      Chris
# 1       Giraffe      Kevin
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
df.columns
# Out:
# Index(['animals', 'owners'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
type(df['animals'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# animals    Mouse
# owners     Chris
# Name: 0, dtype: object

# %%
df.loc[0][1]
# Out:
# 'Chris'

# %%
# copy an existing DataFrame to create a new dataFrame
copy_df = df.copy()
copy_df
# Out:
#         animals     owners
# 0         Mouse      Chris
# 1       Giraffe      Kevin
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
# drop columns

df2 = df.drop(['owners'], axis = 1)

df2
# Out:
#         animals
# 0         Mouse
# 1       Giraffe
# 2         Tiger
# 3           Dog
# 4  Hippopotamus
# 5         Moose
# 6          Bear

# %%
# drop columns

df3 = df.drop(columns = ['owners'])

df3
# Out:
#         animals
# 0         Mouse
# 1       Giraffe
# 2         Tiger
# 3           Dog
# 4  Hippopotamus
# 5         Moose
# 6          Bear

# %%
# drop rows

df4 = df.drop([0,1])
df4
# Out:
#         animals     owners
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
                             ['speed', 'weight']],
                     codes=[[0, 0, 1, 1, 2, 2],
                            [0, 1, 0, 1, 0, 1]])

midx
# Out:
# MultiIndex([(  'lama',  'speed'),
#             (  'lama', 'weight'),
#             (   'cow',  'speed'),
#             (   'cow', 'weight'),
#             ('falcon',  'speed'),
#             ('falcon', 'weight')],
#            )

# %%
df = pd.DataFrame(index=midx, columns=['big', 'small'],
                   data=[[45, 30], [200, 100], [30, 20], [250, 150], [320, 250],[1, 0.8]])

df
# Out:
#                big  small
# lama   speed    45   30.0
#        weight  200  100.0
# cow    speed    30   20.0
#        weight  250  150.0
# falcon speed   320  250.0
#        weight    1    0.8

# %%
df.drop(index='cow', columns='small')
# Out:
#                big
# lama   speed    45
#        weight  200
# falcon speed   320
#        weight    1

# %%
df.drop(index='weight', level=1)
# Out:
#               big  small
# lama   speed   45   30.0
# cow    speed   30   20.0
# falcon speed  320  250.0

# %% [markdown]
# ## Part 1 Task 1
#
# Given the data below, implement each tasks.
#
# <img src="img/df.png" style="height:200px">
#
# (1) Create a DataFrame.
#
# (2) Access the first row data and print it.
#
# (3) Access the first column data (indexed by 'dept') and print it.
#
# (4) Create a new DataFrame by dropping the 2nd column data (indexed by 'floor') from the current DataFrame.

# %%
# (1) Create a DataFrame.
d_list = ['CS', 'Bio', 'Chem', 'Phy', 'Eng']
dept = pd.Series(d_list)

f_list = ['5', '3', '3', '2', '4']
floor = pd.Series(f_list)

frame = {'dept' : dept, 'floor': floor}
df = pd.DataFrame(frame)
df
# Out:
#    dept floor
# 0    CS     5
# 1   Bio     3
# 2  Chem     3
# 3   Phy     2
# 4   Eng     4

# %%
# (2) Access the first row data and print it.
df.iloc[0]
# Out:
# dept     CS
# floor     5
# Name: 0, dtype: object

# %%
# (3) Access the first column data (indexed by 'dept') and print it.

# Accessing the first column data (the dept column) and print it 
print(df.dept)
# Out:
# 0      CS
# 1     Bio
# 2    Chem
# 3     Phy
# 4     Eng
# Name: dept, dtype: object

# %%
# (4) Create a new DataFrame by dropping the 2nd column data (indexed by 'floor') from the current DataFrame.

# Creating a copy of the existing DataFrame to create a new DataFrame
df_copy = df.copy()

# Dropping the 2nd column data ('floor') from the current DataFrame 
df2 = df.drop(columns = ['floor'])

# Print out the results
print("Copy of the original DataFrame: ")
print(df_copy)
print("\n")
print("Old DataFrame with the 2nd column data dropped (indexed by 'floor'): ")
print(df2)
# Out:
# Copy of the original DataFrame:
#    dept floor
# 0    CS     5
# 1   Bio     3
# 2  Chem     3
# 3   Phy     2
# 4   Eng     4
#
#
# Old DataFrame with the 2nd column data dropped (indexed by 'floor'):
#    dept
# 0    CS
# 1   Bio
# 2  Chem
# 3   Phy
# 4   Eng

# %% [markdown]
# ## Part 1 Task 2
#
# Practice with a data file.
#
# (1) Choose one data file from the data folder in the given TW1 folder.
#
# (2) Read the data into a DataFrame.
#
# (3) Access the rows and columns.
#
# (4) Drop some columns.

# %%
# (1) Choose one data file from the data folder in the given TW1 folder.
# (2) Read the data into a DataFrame.
cars = pd.read_csv('./cars.csv')
print(cars)
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
# (3) Access the rows and columns.

# Accessing the first few rows and columns of each table 
print(cars.head())
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
# Only Retrieve data with Make Tesla 

tesla = cars[cars.Make == 'TESLA']
print(tesla)
# Out:
#     YEAR   Make                        Model            Size  (kW) Unnamed: 5  \
# 7   2013  TESLA     MODEL S (40 kWh battery)       FULL-SIZE   270         A1
# 8   2013  TESLA     MODEL S (60 kWh battery)       FULL-SIZE   270         A1
# 9   2013  TESLA     MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 10  2013  TESLA          MODEL S PERFORMANCE       FULL-SIZE   310         A1
# 17  2014  TESLA     MODEL S (60 kWh battery)       FULL-SIZE   225         A1
# 18  2014  TESLA     MODEL S (85 kWh battery)       FULL-SIZE   270         A1
# 19  2014  TESLA          MODEL S PERFORMANCE       FULL-SIZE   310         A1
# 28  2015  TESLA     MODEL S (60 kWh battery)       FULL-SIZE   283         A1
# 29  2015  TESLA     MODEL S (70 kWh battery)       FULL-SIZE   283         A1
# 30  2015  TESLA  MODEL S (85/90 kWh battery)       FULL-SIZE   283         A1
# 31  2015  TESLA                  MODEL S 70D       FULL-SIZE   280         A1
# ...

# %%
# Getting distinct values of the make of the cars. 
print(cars.Make.unique())
# Out:
# ['MITSUBISHI' 'NISSAN' 'FORD' 'SMART' 'TESLA' 'CHEVROLET' 'BMW' 'KIA']

# %%
# (4) Drop some columns.
# Dropping columns: Unnamed: 5; RATING; TYPE; COMB (Le/100 km); COMB (kWh/100 km); (g/km)

cars.drop(['Unnamed: 5', 'RATING', 'TYPE', 'COMB (Le/100 km)', 'COMB (kWh/100 km)', '(g/km)'], axis = 1)
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...
